# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler,OneHotEncoder

# %%
data = pd.read_csv('apple_quality.csv')
data.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840  \
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
data.tail()
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900  \
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN

# %%
data.drop(4000,axis=0,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
data['Acidity'] = data['Acidity'].astype('Float64')

# %%
data.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000  \
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness   Acidity
# count  4000.000000  4000.000000    4000.0
# mean      0.512118     0.498277  0.076877
# std       1.930286     1.874427   2.11027
# min      -5.961897    -5.864599 -7.010538
# 25%      -0.801286    -0.771677 -1.377424
# 50%       0.534219     0.503445  0.022609
# 75%       1.835976     1.766212  1.510493
# max       7.364403     7.237837  7.404736

# %%
data.isnull().sum()
# Out:
# A_id           0
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
data.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
X = data[['Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
       'Ripeness', 'Acidity']]
y = data['Quality']

# %%
numerical_features = [x for x in X.columns if X.dtypes[x] != 'object']
categorical_features = [x for x in X.columns if X.dtypes[x] == 'object']

# %%
numerical_features
# Out:
# ['Size',
#  'Weight',
#  'Sweetness',
#  'Crunchiness',
#  'Juiciness',
#  'Ripeness',
#  'Acidity']

# %%
categorical_features
# Out:
# []

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# 1693  2.903090 -0.748370  -1.608414     0.836871  -0.558577  0.723190  \
# 1954  0.485271 -0.009211  -4.028833     0.804455   1.069991  4.018541
# 2213 -0.334986 -1.667268  -0.104787     2.107930  -3.644783  0.045082
# 2281 -4.759438 -2.516415   0.587103     1.199243   3.218731  2.725957
# 744   0.122972 -2.433090   1.315824     1.138016  -0.401675  0.828748
# ...        ...       ...        ...          ...        ...       ...
# 1740  0.332102 -2.729038  -0.213953     2.392896   0.282413 -2.144787
# 838   1.487181 -1.822071   0.814733     0.802819   1.933550 -1.841884
# 1557  4.485782  0.014331  -1.958082     0.118627   1.627263  1.115202
# 3525 -0.636076 -3.746856   4.377382    -0.886810  -0.655860  2.587461
# 3024 -1.366082 -2.415544   2.057851     0.535387   4.138952 -4.799114
#
#        Acidity
# 1693  0.818821
# 1954  0.554639
# 2213  0.198689
# 2281  5.568768
# 744  -1.031509
# ...        ...
# 1740  -0.15461
# 838    2.44817
# 1557   1.66707
# 3525 -0.482244
# 3024  0.755674
#
# [3200 rows x 7 columns]

# %%
X_test
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness
# 2740 -0.111685  0.489788  -0.333828    -1.265075   0.343857  1.031916  \
# 3180  1.978805 -1.668787   0.160050     1.923281  -1.968770  0.502737
# 3900  0.047628 -2.035774  -1.706659     1.760040   1.669244  1.843260
# 3897 -3.236927 -0.204709   1.172163     1.953748  -0.882900  0.627905
# 2550 -2.037482  1.275922  -1.686684     2.481398  -0.557054  0.648534
# ...        ...       ...        ...          ...        ...       ...
# 1646  0.320943 -4.124308   3.894007    -0.250682   0.524530  2.891306
# 3296  1.339489 -0.984984  -0.245295     1.863707   1.636745 -2.173060
# 3290 -2.520364  0.233835  -5.671517     1.611891  -2.915728  2.817676
# 3915 -4.140536  0.454972   1.667803    -0.341601   3.355342 -0.622478
# 3980 -2.492583 -2.065917   1.081180     1.267673  -1.600722 -2.831947
#
#        Acidity
# 2740  -4.86575
# 3180  1.177379
# 3900  2.753851
# 3897  1.358348
# 2550  2.008481
# ...        ...
# 1646 -0.832732
# 3296  1.108448
# 3290 -1.021048
# 3915 -0.308599
# 3980  0.627117
#
# [800 rows x 7 columns]

# %%
models = {
    'Logistic Regression' : LogisticRegression(),
    'Decison Tree' : DecisionTreeClassifier(),
    'Random Forest' : RandomForestClassifier()
}

for x in range(len(list(models))):
    model = list(models.values())[x]

    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print(model)
    print('Accuracy : ',accuracy_score(y_test,y_pred))
    print('='*50)
# Out:
# LogisticRegression()
# Accuracy :  0.73625
# ==================================================
# DecisionTreeClassifier()
# Accuracy :  0.82125
# ==================================================
# RandomForestClassifier()
# Accuracy :  0.8975
# ==================================================

# %%
param_grid = {'n_estimators':[50,100,150,200,300],
              'criterion':['gini','entropy'],
              'max_depth':[1,3,5,8,None],
              'min_samples_split':[0.1,0.3,0.5,0.7,0.9],
              'min_samples_leaf':[1,2,3,4,5]
}
grid = GridSearchCV(RandomForestClassifier(),param_grid=param_grid,cv=5,verbose=True,n_jobs=-1,scoring='accuracy')

grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1250 candidates, totalling 6250 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 3, 5, 8, None],
#                          'min_samples_leaf': [1, 2, 3, 4, 5],
#                          'min_samples_split': [0.1, 0.3, 0.5, 0.7, 0.9],
#                          'n_estimators': [50, 100, 150, 200, 300]},
#              scoring='accuracy', verbose=True)

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': None,
#  'min_samples_leaf': 3,
#  'min_samples_split': 0.1,
#  'n_estimators': 200}

# %%
best_model = RandomForestClassifier(criterion='gini',max_depth=None,min_samples_leaf=3,min_samples_split=0.1,
n_estimators=200)

# %%
best_model.fit(X_train,y_train)
y_pred = best_model.predict(X_test)

print('Accuracy : ',accuracy_score(y_test,y_pred))
# Out:
# Accuracy :  0.82375
